# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException
from bs4 import BeautifulSoup

# %%
import timeit
start = timeit.default_timer()

count =1
list = []
for i in range(1,11):
    print()
    driver=webdriver.Chrome("C:/Users\kkang/workspace/CRL/Lecture/chromedriver.exe")
    driver.get("https://search.naver.com/search.naver?where=post&sm=tab_jum&query=%EB%8F%99%EB%8C%80%EB%AC%B8%EA%B4%80%EA%B4%91")

    driver.find_element_by_xpath('//*[@id="main_pack"]/div[2]/ul/li[' +str(i)+ ']/dl/dt/a').click()
    
    driver.switch_to.window(driver.window_handles[1])
    try:
        body =driver.find_element_by_xpath('//*[@id="whole-border"]')
        print(body.text)
        driver.quit()
    except NoSuchElementException:
        print("pass")
        driver.quit()
#title=soups.select("div.tit-box span.b")
#print(title[0].text)
    count +=1
#driver.switch_to.window(driver.window_handles[-1])
stop = timeit.default_timer()
print(stop - start)
#html=driver.page_source
#soup=bs(html,'html.parser')
#driver.quit()
#driver.switch_to.window(driver.window_handles[0])
#driver.find_element_by_xpath('//*[@id="main_pack"]/div[2]/ul/li[2]/dl/dt/a').click()
# Out:
# pass
#
# pass
#
# pass
#
# pass
#
# pass
#
# pass
#
# pass
#
# pass
#
# pass
#
# pass
# 78.5132164000006

# %%
driver=webdriver.Chrome("C:/Users\kkang/workspace/CRL/Lecture/chromedriver.exe")
driver.get("https://search.naver.com/search.naver?where=post&sm=tab_jum&query=%EB%8F%99%EB%8C%80%EB%AC%B8%EA%B4%80%EA%B4%91")
driver.find_element_by_xpath('//*[@id="main_pack"]/div[2]/ul/li[2]/dl/dt/a').click()

# %%
#last_tab = driver.window_handles[-1]
#driver.switch_to.window(window_name=last_tab)

body =driver.find_element_by_xpath('//*[@id="printPost1"]/tbody')
print(body.text)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-32-35d2e4dc9fdd> in <module>
#       2 #driver.switch_to.window(window_name=last_tab)
#       3
# ----> 4 body =driver.find_element_by_xpath('//*[@id="printPost1"]/tbody')
#       5 print(body.text)
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="printPost1"]/tbody"}
#   (Session info: chrome=76.0.3809.87)

# %%
import requests
import os
import sys
client_id = 'TW7kAezMnTu_WFX3CuPS'
client_secret = 'AYU9X8uehE'
encText = urllib.parse.quote("남이섬")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display=100&start=2" # json 결과
header_params =  {"X-Naver-Client-Id" : client_id, "X-Naver-Client-Secret" : client_secret}
res = requests.get(url, headers= header_params)

if res.status_code== 200:
    data =res.json()
    print(data)
else:
    print("Error Code:", res.status_code)
# Out:
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display=100&start=1" # json 결과
header_params =  {"X-Naver-Client-Id" : client_id, "X-Naver-Client-Secret" : client_secret}
res = requests.get(url, headers= header_params)

#if res.status_code== 200:
data =res.json()
#    print(data)
#else:
#    print("Error Code:", res.status_code)
for num, item in enumerate(data['items']):
    print(num +1 , item['link'])
# Out:
# 1 https://blog.naver.com/roynmin?Redirect=Log&logNo=221582576251
# 2 https://blog.naver.com/wlsgml9552?Redirect=Log&logNo=221564516430
# 3 https://blog.naver.com/namipr?Redirect=Log&logNo=221605165926
# 4 https://blog.naver.com/alsk_2919?Redirect=Log&logNo=221599456697
# 5 https://blog.naver.com/onlyoneg123?Redirect=Log&logNo=221578564852
# 6 https://blog.naver.com/kimhanna0518?Redirect=Log&logNo=221582295449
# 7 https://blog.naver.com/sodam3826?Redirect=Log&logNo=221584952496
# 8 https://blog.naver.com/kji206?Redirect=Log&logNo=221563342869
# 9 https://blog.naver.com/marzanara?Redirect=Log&logNo=221595968043
# 10 https://blog.naver.com/nongnim?Redirect=Log&logNo=221598648550
# 11 https://blog.naver.com/kwonsista?Redirect=Log&logNo=221587496601
# 12 https://blog.naver.com/mulin0913?Redirect=Log&logNo=221584473788
# 13 https://blog.naver.com/sirin1004?Redirect=Log&logNo=221606630821
# 14 https://blog.naver.com/bono1092?Redirect=Log&logNo=221567732583
# 15 https://blog.naver.com/kimsookyung_?Redirect=Log&logNo=221579050919
# 16 https://blog.naver.com/kjy_0423?Redirect=Log&logNo=221594472846
# 17 https://blog.naver.com/eunbyul910909?Redirect=Log&logNo=221577932392
# 18 https://blog.naver.com/oes35oes?Redirect=Log&logNo=221551358613
# 19 https://blog.naver.com/dneuddl?Redirect=Log&logNo=221601319278
# 20 https://blog.naver.com/minjae0413?Redirect=Log&logNo=221596375614
# 21 https://blog.naver.com/woosh1357?Redirect=Log&logNo=221600826919
# 22 https://blog.naver.com/sjsvosxja75?Redirect=Log&logNo=221595045909
# 23 https://blog.naver.com/turpu?Redirect=Log&logNo=221561050546
# 24 https://blog.naver.com/oioi3030?Redirect=Log&logNo=221584164310
# 25 https://blog.naver.com/despp?Redirect=Log&logNo=221566408057
# 26 https://blog.naver.com/anndam?Redirect=Log&logNo=221557991712
# 27 https://blog.naver.com/dlsnf?Redirect=Log&logNo=221580036378
# 28 https://blog.naver.com/2party?Redirect=Log&logNo=221580924448
# 29 https://blog.naver.com/pink_ladys?Redirect=Log&logNo=221567057331
# 30 https://blog.naver.com/rladmswl5844?Redirect=Log&logNo=221586220744
# 31 https://blog.naver.com/oes35oes?Redirect=Log&logNo=221578183629
# 32 https://blog.naver.com/happy_love02?Redirect=Log&logNo=221588174827
# 33 https://blog.naver.com/pranchiger?Redirect=Log&logNo=221577587016
# 73 https://blog.naver.com/kinoops?Redirect=Log&logNo=221568602472
# 74 https://blog.naver.com/eenri?Redirect=Log&logNo=221589439955
# 75 https://blog.naver.com/pihcap?Redirect=Log&logNo=221568430949
# 76 https://blog.naver.com/needme33?Redirect=Log&logNo=221606988563
# 77 https://blog.naver.com/hyu37365?Redirect=Log&logNo=221587872730
# 78 https://blog.naver.com/namipr?Redirect=Log&logNo=221589915743
# 79 https://blog.naver.com/todwmf?Redirect=Log&logNo=221586588359
# 80 https://blog.naver.com/sscd0808?Redirect=Log&logNo=221603003169
# 81 https://blog.naver.com/31sohn?Redirect=Log&logNo=221597818335
# 82 https://blog.naver.com/ladybrown23?Redirect=Log&logNo=221582301811
# 83 https://blog.naver.com/psyjoa?Redirect=Log&logNo=221581121356
# 84 https://blog.naver.com/namipr?Redirect=Log&logNo=221592989403
# 85 https://blog.naver.com/yunjung0419?Redirect=Log&logNo=221573976700
# 86 https://blog.naver.com/heesu2071?Redirect=Log&logNo=221604522337
# 87 https://blog.naver.com/lgpowerfox?Redirect=Log&logNo=221596409278
# 88 https://blog.naver.com/2705b?Redirect=Log&logNo=221599506354
# 89 https://blog.naver.com/lsh2173921?Redirect=Log&logNo=221586578261
# 90 https://blog.naver.com/jjj52?Redirect=Log&logNo=221565855192
# 91 https://blog.naver.com/freedetox?Redirect=Log&logNo=221568300822
# 92 https://blog.naver.com/namipr?Redirect=Log&logNo=221584719629
# 93 https://blog.naver.com/thwnd4311?Redirect=Log&logNo=221605943097
# 94 https://blog.naver.com/younza?Redirect=Log&logNo=221596693010
# 95 http://blog.daum.net/djtk1004/7638783
# 96 http://blog.daum.net/dowori/3698679
# 97 https://ohdesign.tistory.com/entry/%EB%82%A8%EC%9D%B4%EC%84%AC-%EB%B0%B0%EC%8B%9C%EA%B0%84%ED%91%9C-%EB%B0%8F-%EB%B0%B0%EA%B0%92-%EC%A0%95%EB%B3%B4-%EC%95%8C%EC%95%84%EB%B3%B4%EA%B8%B0
# 98 https://taibale.tistory.com/3012
# 99 http://blog.daum.net/by1594/275
# 100 https://blog.naver.com/bancoco?Redirect=Log&logNo=221578047156

# %%
count =1
list = []
for i in range(1,10):
    
    driver=webdriver.Chrome("C:/chromedriver_win32/chromedriver.exe")
    driver.get("https://search.naver.com/search.naver?where=post&sm=tab_jum&query=%EB%8F%99%EB%8C%80%EB%AC%B8%EA%B4%80%EA%B4%91")

    driver.find_element_by_xpath('//*[@id="main_pack"]/div[2]/ul/li[' +str(count)+ ']/dl/dt/a').click()
    
    driver.switch_to.window(driver.window_handles[-1])
    try:
        body =driver.find_element_by_xpath("/html/body")
        list.append(body.text)
        driver.quit()
    except NoSuchElementException:
        print("pass")
        driver.quit()
#title=soups.select("div.tit-box span.b")
#print(title[0].text)
    count +=1
#driver.switch_to.window(driver.window_handles[-1])
print(list)
