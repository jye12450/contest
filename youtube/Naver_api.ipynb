# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "TW7kAezMnTu_WFX3CuPS"
client_secret = "AYU9X8uehE"
encText = urllib.parse.quote("에어컨")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +"&display=100" # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 05 Aug 2019 17:46:04 +0900",
# "total": 7639264,
# "start": 1,
# "display": 100,
# "items": [
# {
# "title": "수원<b>에어컨</b>설치 늦었다고 생각될때 ^^",
# "link": "https:\/\/blog.naver.com\/boom0304?Redirect=Log&logNo=221592277075",
# "description": "알고보니 <b>에어컨</b>을 그냥 처리하고 왔단 것…ㅋㅋㅋ 그래서 새로 이사온 집이니까 새 <b>에어컨</b>으로 해야겠다 싶어서 알아보니까 요즘 또 성수기잖아요? 그래서그런지 제품은 많은데 너무너무 가격이 비싼거에요... ",
# "bloggername": "콤돌이의 내츄럴키친",
# "bloggerlink": "https://blog.naver.com/boom0304",
# "postdate": "20190722"
#
# },
# {
# "title": "실외기 없는 <b>에어컨</b> 바툼, 소형 <b>에어컨</b>으로 대만족!!",
# "link": "https:\/\/blog.naver.com\/j00000a?Redirect=Log&logNo=221590521307",
# "description": "ㅠㅠ 안방에 벽걸이<b>에어컨</b>도 설치하지말라고...ㅠㅠ 덕분에 2년을 정말 숨막히는 더위속에서 살았어요.. 이사하면 제일먼저 방방마다 <b>에어컨</b> 놓아야지 벼르고 벼르며 침대나 냉장고같은 가전가구보다 <b>에어컨</b>을... ",
# "bloggername": "즐거운 바람이 분다♪",
# "bloggerlink": "https://blog.naver.com/j00000a",
# "postdate": "20190720"
#
# },
# {
# "title": "신일 이동식 <b>에어컨</b> 사려했는데 결국 냉풍기로",
# "link": "https:\/\/blog.naver.com\/daily__y?Redirect=Log&logNo=221600166987",
# "description": "급하게 집을 구하고 옮기느라 꼼꼼히 체크를 못한것도 있지만 <b>에어컨</b>이 안방에만 있고 거실에는 없더라구요 ^^.... 그래서 급하게 검색하다가 신일 이동식 <b>에어컨</b>을 알아보았어요. 디자인은 하얀색으로... ",
# "bloggername": "꿈꾸는세상",
# "bloggerlink": "https://blog.naver.com/daily__y",
# "postdate": "20190730"
#
# },
# {
# "title": "템피아 이동식<b>에어컨</b> 집에서 쓰기 최고!",
# "link": "https:\/\/blog.naver.com\/slap16?Redirect=Log&logNo=221603056735",
# "description": "템피아 이동식<b>에어컨</b> 집에서 쓰기 최고! 여름은 저에게는 정말 최악의 계절인 것 같아요 몇 십년을... 느낌이라 <b>에어컨</b> 없이는 도저히 못살겠더라구요 조금만 햇볕을 쐬거나 뜨겁고 축축한 야외에 조금만... ",
# "bloggername": "I've got a dream that I'm gonna come true !",
# "bloggerlink": "https://blog.naver.com/slap16",
# "postdate": "20190802"
#
# },
# {
# "title": "광주<b>에어컨</b>청소 친환경으로",
# "link": "https:\/\/blog.naver.com\/pamilly?Redirect=Log&logNo=221590926094",
# "description": "여름에 <b>에어컨</b>이 없이도 선풍기만으로도 지내기도 했던 것 같은데 ㅎㅎ 요즘엔 정말 <b>에어컨</b> 없이는 못살 것만 같아요 특히 요즘의 여름은 기온과 습한 정도가 장난이 아니라는 사실을 뉴스나 SNS 다양한 매체를... ",
# "bloggername": "퍼펙트와 건강한치아",
# "bloggerlink": "https://blog.naver.com/pamilly",
# "postdate": "20190720"
#
# },
# {
# "title": "수원<b>에어컨</b>설치 배관부터 꼼꼼히!",
# "link": "https:\/\/blog.naver.com\/guitarfire?Redirect=Log&logNo=221598872013",
# "description": "되겠지하고 <b>에어컨</b>은 잘 켜지도 않았어요 제방에 냉방이란걸 모르고 살았으니 솔직히 더위도 많이... 어찌하다가 이사를 하게되는 상황이 되었구 여름걱정에 <b>에어컨</b>설치 비용부터 여러가지를... ",
# "bloggername": "lee g i",
# "bloggerlink": "https://blog.naver.com/guitarfire",
# "postdate": "20190729"
#
# },
# {
# "title": "수원<b>에어컨</b>청소 속시원히 해결!",
# "link": "https:\/\/blog.naver.com\/wepaintpark?Redirect=Log&logNo=221593333161",
# "description": "수원<b>에어컨</b>청소 속시원히 해결! 안녕하세요 여러분들~ 날씨가 엄청 더워졌네요!! 저희집은 아파트 꼭대기탑층이라 다른집들보다 훨~씬 더운편인데요. 다른집들보다 일찍 <b>에어컨</b>을 개시했는데 세상에나.. 이게... ",
# "bloggername": "히뜨다히뚜~!",
# "bloggerlink": "https://blog.naver.com/wepaintpark",
# "postdate": "20190723"
#
# },
# {
# "title": "파세코 창문형 <b>에어컨</b> 22%DC 특가 후기~",
# "link": "https:\/\/blog.naver.com\/dneuddl?Redirect=Log&logNo=221596327687",
# "description": "저도 뭐 여름철에 <b>에어컨</b> 들이고 싶었다가 벽에 구멍 뚫어서 설치하는 것도 부담스럽고 요샌 또... 창문형 <b>에어컨</b> 보고 나서 이 엄청난 신박함에 끌려 사왔었는데요. 요새 제 친구들도 <b>에어컨</b> 때문에 엄청... ",
# "bloggername": "이야기마당",
# "bloggerlink": "https://blog.naver.com/dneuddl",
# "postdate": "20190726"
#
# },
# {
# "title": "캐리어<b>에어컨</b> 렌탈 삼성으로 선택한 이유 (무풍이라 더 좋음!)",
# "link": "https:\/\/blog.naver.com\/lenemarl?Redirect=Log&logNo=221603358552",
# "description": "캐리어<b>에어컨</b> 렌탈 삼성으로 선택한 이유 (무풍이라 더 좋음!) 안녕하세요!! 요즘 기분이 정말 썩 좋지... 싶어서 <b>에어컨</b>을 찾아보는데, 왠 걸.. 왜이리 비싼가요 ㅠㅠ 좀 마음에 든다 싶으면 150만원이 훌쩍... ",
# "bloggername": "아누리 블로그",
# "bloggerlink": "https://blog.naver.com/lenemarl",
# "postdate": "20190802"
#
# },
# {
# "title": "성남 <b>에어컨</b>청소! 4년 만에 청소한 후기",
# "link": "https:\/\/blog.naver.com\/wonk711?Redirect=Log&logNo=221601242656",
# "description": "저희는 벌써 일찌감치 <b>에어컨</b>을 틀기 시작했는데, 거의 횟수로 4년정도 되었어요. 그런데 올해 첫 <b>에어컨</b>을 작동시키는데,,,,,,, 틀자마자 퀴퀴한 냄새가 나기 시작하더라구요. 그래서 항상 에어켠 켜고 나서는 약... ",
# "bloggername": "지구산책 Diary",
# "bloggerlink": "https://blog.naver.com/wonk711",
# "postdate": "20190801"
#
# },
# {
# "title": "기억하세요. 화성벽걸이<b>에어컨</b>청소 전문 주니아빠",
# "link": "https:\/\/blog.naver.com\/rhksdn7489?Redirect=Log&logNo=221587958553",
# "description": "화성벽걸이<b>에어컨</b>청소 전문 주니아빠 저 드디어 한국 민속촌 다녀왔어요. 제가 그동안 민속촌 민속촌... 그래서 <b>에어컨</b>을 자연스럽게 틀었는데, 이상하게 먼지 냄새가 그렇게 나는거에요. 신랑도 샤워하고... ",
# "bloggername": "주니아빠 공식블로그",
# "bloggerlink": "https://blog.naver.com/rhksdn7489",
# "postdate": "20190730"
#
# },
# {
# "title": "이동식 <b>에어컨</b> 단점",
# "link": "https:\/\/blog.naver.com\/lstak?Redirect=Log&logNo=221604496056",
# "description": "이동식 <b>에어컨</b>의 단점을 알고 사용합시다. 원룸에 세입자로 살고 있는데 벽걸이 <b>에어컨</b>이 가스가 샌다. 6~8일 정도 지나면 냉매가 거의다 새어 차가운 바람이 나오지 않는다. LG <b>에어컨</b> AS 기사들이 여러번... ",
# "bloggername": "독특의 작은 도전",
# "bloggerlink": "https://blog.naver.com/lstak",
# "postdate": "20190803"
#
# },
# {
# "title": "대전<b>에어컨</b>설치 국민으로 선택!",
# "link": "https:\/\/blog.naver.com\/boom0304?Redirect=Log&logNo=221593180570",
# "description": "습하고 푹푹 찌는 여름이라 선풍기로 잘 버텨볼려다가 더이상 못참을것같아 <b>에어컨</b>을 설치하기로했습니다 대전<b>에어컨</b>설치를 찾던 중 괜찮은 곳을 찾았어요! 많은곳이 있지만 지인들의 추천을 우선으로... ",
# "bloggername": "콤돌이의 내츄럴키친",
# "bloggerlink": "https://blog.naver.com/boom0304",
# "postdate": "20190723"
#
# },
# {
# "title": "파세코 창문형 <b>에어컨</b> 설치방법, 장단점 후기",
# "link": "https:\/\/blog.naver.com\/ishine75?Redirect=Log&logNo=221570500957",
# "description": "요즘 홈쇼핑에서 엄청난 인기를 모으는 가전이 있는데 바로 파세코 창문형 <b>에어컨</b>입니다. 원룸이나 <b>에어컨</b> 설치가 애매한 공간에서 간단하게 설치할 수 있고, 실외기가 필요 없기 때문에 따로... ",
# "bloggername": "꽃잔의 감성리뷰",
# "bloggerlink": "https://blog.naver.com/ishine75",
# "postdate": "20190626"
#
# },
# {
# "title": "휴대용 <b>에어컨</b> 바툼, 예쁘고 시원한 미니냉풍기!",
# "link": "https:\/\/blog.naver.com\/j00000a?Redirect=Log&logNo=221604179128",
# "description": "<b>에어컨</b>을 팡팡 켜긴 전기료가 부담되고.. 안켜긴 푹푹 찌는 힘든 무더운 날씨, 잘 이겨내고 계신가요?! ㅠㅠ 전 직업이 연구원이라 연구실로 출근을 하고있는데 하필이면 제 자리 바로 뒤에 <b>에어컨</b>이 있어서 제... ",
# "bloggername": "즐거운 바람이 분다♪",
# "bloggerlink": "https://blog.naver.com/j00000a",
# "postdate": "20190803"
#
# },
# {
# "title": "하이마트 홈케어 서비스 중에서 <b>에어컨</b> 클리닝 해봤습니다",
# "link": "https:\/\/blog.naver.com\/meesoda?Redirect=Log&logNo=221606169095",
# "description": "각종 뉴스나 신문을 보면서 집에 세탁기와 <b>에어컨</b>은 수시로 청소를 해줘야겠다라고 많이 생각하고... ~ 그래서 이번 여름에는 아이들과 계속해서 사용하게 되는 <b>에어컨</b> 클리닝이 급할 것 같더라고요. 분명... ",
# "bloggername": "게으름뱅이그녀의 패션,뷰티",
# "bloggerlink": "https://blog.naver.com/meesoda",
# "postdate": "20190805"
#
# },
# {
# "title": "서울<b>에어컨</b>청소 스탠드<b>에어컨</b>청소E케어와 친환경청소!",
# "link": "https:\/\/blog.naver.com\/pamilly?Redirect=Log&logNo=221604232552",
# "description": "서울<b>에어컨</b>청소 스탠드<b>에어컨</b>청소E케어와 친환경청소! 안녕하세요, 전국 팔도 방방곳곳을 띄어다니면서 여러분들이 건강을 생각한 친환경 청소 업체 E-케어 입니다. 현재 낮 최고 기온이 36도에 다 다른다고 하여... ",
# "bloggername": "전주 예그린",
# "bloggerlink": "https://blog.naver.com/pamilly",
# "postdate": "20190803"
#
# },
# {
# "title": "[김진백 기자] 열차 속 <b>에어컨</b>의 모든 것",
# "link": "https:\/\/blog.naver.com\/krriblog?Redirect=Log&logNo=221599684184",
# "description": "우리가 타고 다니는 열차 안에서 <b>에어컨</b>이 어떤 방식으로 작동되는지 알아보겠습니다. [출처: 서울교통공사, 픽사베이] 해가 갈수록 더워지는 여름에는 열차 안에서 <b>에어컨</b>은 필수인데요. 가끔 열차 안의... ",
# "bloggername": "한국철도기술연구원",
# "bloggerlink": "https://blog.naver.com/krriblog",
# "postdate": "20190730"
#
# },
# {
# "title": "인버터<b>에어컨</b> 냉방 방법... 완화 전기요금표 (LG듀얼<b>에어컨</b>)",
# "link": "https:\/\/blog.naver.com\/suragen83?Redirect=Log&logNo=221605924255",
# "description": "LG전자 휘센 듀얼<b>에어컨</b> 18년형 17평형 모델 FQ17V8DWHN 냉방 소비 전력 최소 330W ~ 정격 2,050W... 냉방은 <b>에어컨</b>으로.... 인터넷 하다가 봤는데 설명서에 있는 내용도 안 읽어봤는지 기능에 대해 물어보고 어떻게... ",
# "bloggername": "낚고 낚이는 인생... 사는 게 죄인 남자...",
# "bloggerlink": "https://blog.naver.com/suragen83",
# "postdate": "20190805"
#
# },
# {
# "title": "스텐드 천장형 <b>에어컨</b>에서 물떨어짐 누수탐지 물샘 잡았다 요놈!!",
# "link": "https:\/\/blog.naver.com\/nuri_jubang1?Redirect=Log&logNo=221604245380",
# "description": "<b>에어컨</b> 누수! 잡아라 요놈!! 천정에서 물이 뚝뚝... 떨어진다요... #천장형<b>에어컨</b>누수 문제로 급하게 연락이왔습니다. 물이 여기서 떨어져서 영업을 할 수가 없다고 하시는 사장님... 과연 어떤 상황인지 현장으로... ",
# "bloggername": "누리JB",
# "bloggerlink": "https://blog.naver.com/nuri_jubang1",
# "postdate": "20190803"
#
# },
# {
# "title": "신일 이동식<b>에어컨</b> SMA-P12000AU 사용해보니 시원해~",
# "link": "https:\/\/blog.naver.com\/prettydaezi?Redirect=Log&logNo=221605506081",
# "description": "신일 이동식<b>에어컨</b> SMA-P12000AU 사용해보니 시원해~ 안녕하세요. 네이버 뷰스타 달콤줄리에요. 요즘 폭염... 특히 저희 집의 경우 시스템 <b>에어컨</b>을 설치해서 사용하고 있는데요. 안방, 거실, 작업방, 주방, 아이들... ",
# "bloggername": "뷰티/패션 블로그 달콤줄리",
# "bloggerlink": "https://blog.naver.com/prettydaezi",
# "postdate": "20190804"
#
# },
# {
# "title": "부천<b>에어컨</b>설치 무더운 여름나기의 시작!",
# "link": "https:\/\/blog.naver.com\/jhnjell?Redirect=Log&logNo=221566407124",
# "description": "집엔 <b>에어컨</b>이 설치되어 있지 않아 이런 일이 일어난 거죠 계속해서 미루다 더 이상 시간을 지체할 수... 미리 <b>에어컨</b> 설치를 해보는 게 어떻겠냐며 말씀 드렸더니 곧 오케이 하셨습니다. 신이 난 저는 여기저기... ",
# "bloggername": "YOU ARE THE MUSIC IN ME",
# "bloggerlink": "https://blog.naver.com/jhnjell",
# "postdate": "20190620"
#
# },
# {
# "title": "<b>에어컨</b> 선풍기 이제는 서큘레이터",
# "link": "https:\/\/blog.naver.com\/rlaghlfh?Redirect=Log&logNo=221601269766",
# "description": "<b>에어컨</b> 선풍기 이제는 서큘레이터 내일이면 이제 8월로 접어들고 약 1달간은 엄청난 더위가 예상된다고... 여름에는 <b>에어컨</b>과 선풍기를 동시에 같이 사용하게되는데 그 이유는 다들 아실거예요 <b>에어컨</b>만... ",
# "bloggername": "단지뷰 블로그",
# "bloggerlink": "https://blog.naver.com/rlaghlfh",
# "postdate": "20190731"
#
# },
# {
# "title": "여름 습기 잡는 필수가전! <b>에어컨</b>, 건조기 덕분 :)",
# "link": "https:\/\/blog.naver.com\/zaawoo?Redirect=Log&logNo=221602694771",
# "description": "먼저 창문 활짝 열어놓고 <b>에어컨</b>부터 틀었답니다. 와우 집안 온도 30도~!! 예전에는 밖이 아무리 더워도... 저희 집은 LG 휘센 <b>에어컨</b>을 사용 중인데요. 리모컨에 좌측 회전 버튼을 3초간 누르면 습도를 알 수... ",
# "bloggername": "자애, 행복하기에도 모자란 날들",
# "bloggerlink": "https://blog.naver.com/zaawoo",
# "postdate": "20190802"
#
# },
# {
# "title": "삼성<b>에어컨</b> 청소(셀프+벽걸이까지)",
# "link": "https:\/\/blog.naver.com\/bsh2haha?Redirect=Log&logNo=221555419270",
# "description": "셀프 삼성<b>에어컨</b> 청소를 지난해 포스팅 했었는데 벌써 1년이 지났네요. 날씨가 더워지면서 더이상 선풍기로 버틸 수 없어 <b>에어컨</b> 청소를 했습니다. 처음 <b>에어컨</b>을 뜯는(?)분들은 엄청 고민하실거예요 저도 첨에... ",
# "bloggername": "달콤한 부부의 세상사는 이야기",
# "bloggerlink": "https://blog.naver.com/bsh2haha",
# "postdate": "20190605"
#
# },
# {
# "title": "자동차 <b>에어컨</b> 가스 충전!",
# "link": "https:\/\/blog.naver.com\/nahlee8?Redirect=Log&logNo=221582419566",
# "description": "원고 쓸 일이 있어 밤샘하고 한숨도 안 자고 정오 무렵까지 일하다가 긴한 볼 일이 있어 운전하고 나갔는데 <b>에어컨</b> 바람이 영 시원하지가 않다. 이 더위에 왜 또 <b>에어컨</b>이 말썽이람~ 뙤약볕에 세워뒀다가 볼일... ",
# "bloggername": "마리마더의 cooking & living",
# "bloggerlink": "https://blog.naver.com/nahlee8",
# "postdate": "20190710"
#
# },
# {
# "title": "삼성 <b>에어컨</b> 청소 셀프로 제대로",
# "link": "https:\/\/blog.naver.com\/dukilove0314?Redirect=Log&logNo=221598216938",
# "description": "삼성 <b>에어컨</b> 청소 셀프 로 했답니다. 업체를 부르면 가격대가 높다보니 유투브에 친절하게 설명해서 올려주신분들의 내용을 참고해서 ! 제가 집에서 셀프로 직접 했답니다. 오늘의 주인공인 삼성 <b>에어컨</b> 청소... ",
# "bloggername": "더키럽♥",
# "bloggerlink": "https://blog.naver.com/dukilove0314",
# "postdate": "20190728"
#
# },
# {
# "title": "쉐보레 크루즈 바디쉴드 자동차 <b>에어컨</b> 필터 교체방법",
# "link": "https:\/\/blog.naver.com\/adela08181?Redirect=Log&logNo=221604988410",
# "description": "바디쉴드 5중 <b>에어컨</b>필터로 교체하니 바람도 빵빵~방법도 쉽네 내가 무엇을 마시고 있던 거지? 부모님께 차를 빌려서 타고 있는지 어언 1년이 지났는데...몰랐습니다. 자동차 <b>에어컨</b> 필터를 1년에 1~2회를... ",
# "bloggername": "리쓰리월드",
# "bloggerlink": "https://blog.naver.com/adela08181",
# "postdate": "20190804"
#
# },
# {
# "title": "LG 스탠드 <b>에어컨</b> 청소 :: <b>에어컨</b> 냄새 안나게 하는 방법... ",
# "link": "https:\/\/blog.naver.com\/cestbon0729?Redirect=Log&logNo=221602072792",
# "description": "매년 <b>에어컨</b> 켜면 처음에 시큼한 (?) 곰팡이 냄새가 날때가 있어요. 표니랑 한달 전쯤 엘지 스탠드 <b>에어컨</b> 셀프청소 했었던 사진인데 도움이 되었으면 좋겠네요. 둘다 정신없이 청소하느라 꼼꼼하게 사진은 못... ",
# "bloggername": "긍꽁이 일상",
# "bloggerlink": "https://blog.naver.com/cestbon0729",
# "postdate": "20190801"
#
# },
# {
# "title": "셀프 <b>에어컨</b>청소 실패기",
# "link": "https:\/\/blog.naver.com\/cheimh?Redirect=Log&logNo=221601183487",
# "description": "<b>에어컨</b> 청소가 하고싶은데 누굴 부르는게 좀... 그리고 아무도 아무것도 못믿는 나 ㅋㅋㅋㅋ 집안 공기를 담당하는 <b>에어컨</b>에 소독제 같은거 뿌리는 것도 시르구요.. 근데, <b>에어컨</b>에서 먼지 곰팡이 그런 냄새가... ",
# "bloggername": "악마토끼의 달큰한 유혹~♡",
# "bloggerlink": "https://blog.naver.com/cheimh",
# "postdate": "20190731"
#
# },
# {
# "title": "건강한 여름 나기! <b>에어컨</b>·제습기 관리법",
# "link": "https:\/\/blog.naver.com\/kead1?Redirect=Log&logNo=221599941676",
# "description": "<b>에어컨</b>·제습기 관리법 어느덧 장마가 지고 본격적인 더위가 시작됐어요. 이처럼 덥고 습한 여름에는... 한국장애인고용공단이 소개한 여름철 건강을 지키는 <b>에어콘</b>, 제습기 사용팁! 오늘 나왔던 관리법에 따라... ",
# "bloggername": "한국장애인고용공단 공식블로그",
# "bloggerlink": "https://blog.naver.com/kead1",
# "postdate": "20190730"
#
# },
# {
# "title": "부산<b>에어컨</b>가스충전 , 언제하면 되나요 ?",
# "link": "https:\/\/blog.naver.com\/cleanhomekr?Redirect=Log&logNo=221592594722",
# "description": "어제 까지는 관심밖이었던 <b>에어컨</b> 이었지만 오늘부터는 주인공 이네요. 갑작스런 폭염에 <b>에어컨</b>을 틀었는데....텁텁한 바람이 나온다면 큰일이지요. 미리 미리 점검하고 .....폭염에 대비 해야겠습니다.... ",
# "bloggername": "사랑은마법",
# "bloggerlink": "https://blog.naver.com/cleanhomekr",
# "postdate": "20190722"
#
# },
# {
# "title": "부천 <b>에어컨</b> 가스 충전~!!<b>에어컨</b> 이전설치 저렴하고 빠른곳!!",
# "link": "https:\/\/blog.naver.com\/rlawls307?Redirect=Log&logNo=221590940912",
# "description": "이사는 이삿짐센터에서 알아서 해주시니 걱정할것이 없지만, <b>에어컨</b>은 전문가들에게 맡기라는 말들이 있어 <b>에어컨</b>설치 잘하는 곳을 여러군데를 알아보았습니다. 여러군데를 비교해보다가 부천 시원 <b>에어컨</b>... ",
# "bloggername": "일상을 여행처럼. 여행을 일상처럼~",
# "bloggerlink": "https://blog.naver.com/rlawls307",
# "postdate": "20190720"
#
# },
# {
# "title": "군포벽걸이<b>에어컨</b>청소 먼지와 곰팡이 완벽 차단",
# "link": "https:\/\/blog.naver.com\/rhksdn7489?Redirect=Log&logNo=221604182588",
# "description": "군포벽걸이<b>에어컨</b>청소 먼지와 곰팡이 완벽 차단 여러분 안녕하세요? 날씨가 점점 더워지고 있어요. 작년 여름에 심각하게 더워서 이번 여름은 어떨지 벌써부터 두려운데요. 하루라도 빨리 <b>에어컨</b> 설치나 청소를... ",
# "bloggername": "주니아빠 공식블로그",
# "bloggerlink": "https://blog.naver.com/rhksdn7489",
# "postdate": "20190805"
#
# },
# {
# "title": "LG 휘센 <b>에어컨</b>으로 견디는 여름철 무더위",
# "link": "https:\/\/blog.naver.com\/ha_tak?Redirect=Log&logNo=221605794092",
# "description": "호텔에 머물면서 <b>에어컨</b>을 빵빵하게 틀고, 이불을 덮고 지내는 사치를 만끽하는 것이다. 이렇게 부리는... 사실 <b>에어컨</b>이 최고임 그런데 여기서 재미있는 게 있다. 우리나라를 탈출해서 해외로 나가더라도... ",
# "bloggername": "리뷰빌런 하텍",
# "bloggerlink": "https://blog.naver.com/ha_tak",
# "postdate": "20190805"
#
# },
# {
# "title": "시스템 <b>에어컨</b> 청소 루헨스 케어링으로 깔끔하게",
# "link": "https:\/\/blog.naver.com\/origan75?Redirect=Log&logNo=221586330290",
# "description": "사용하는 <b>에어컨</b>은 평소에는 느끼지 못하고 있다가 본격적으로 사용할 여름이 다가오면 <b>에어컨</b> 청소를 해야하는데 어쩌나 하면서 고민하게 되더라구요 더군다나 저희집은 남편과 아들이 비염을 항상 앓고... ",
# "bloggername": "횬스타일",
# "bloggerlink": "https://blog.naver.com/origan75",
# "postdate": "20190715"
#
# },
# {
# "title": "<b>에어컨</b> 전기료 절약 방법",
# "link": "https:\/\/blog.naver.com\/login88?Redirect=Log&logNo=221602356644",
# "description": "그나마 집이나 사무실 또는 실내에 들어가면 <b>에어컨</b>이 있어 다행입니다. 하지만 <b>에어컨</b>은 여름철 전기료 상승의 주범입니다. 그렇다면 어떻게 효율적으로 <b>에어컨</b>을 사용해야 전기료를 절약할 수 있을까요? 1.... ",
# "bloggername": "투자마법사의 블로그",
# "bloggerlink": "https://blog.naver.com/login88",
# "postdate": "20190801"
#
# },
# {
# "title": "LG <b>에어컨</b> 추천, 휘센이 있어 올여름 걱정 없어요",
# "link": "https:\/\/blog.naver.com\/witchyoli?Redirect=Log&logNo=221583164322",
# "description": "이번에 이사하면서 가장 먼저 이전 설치 예약해 놓은 #LG휘센<b>에어컨</b> . 혹여 성수기와 겹쳐서 제때 못... ^^ 올여름 폭염으로부터 걱정 없이 보내게 해 줄 저의 최애 가전 #LG<b>에어컨</b> 이 완벽하게 설치되어... ",
# "bloggername": "욜리홈쿡",
# "bloggerlink": "https://blog.naver.com/witchyoli",
# "postdate": "20190711"
#
# },
# {
# "title": "차 <b>에어컨</b> 냄새 애프터블로우 시공 차량필수템이죠!",
# "link": "https:\/\/blog.naver.com\/lopil22?Redirect=Log&logNo=221600814859",
# "description": "차 <b>에어컨</b> 냄새 제거 애프터 블로우 시공 후기 이번 여름은 아이가 부쩍 커서 그런지 유난히도 더운 것 같아요. 열 많은 울 동그리와 다니다 보면 <b>에어컨</b>은 필수랍니다. 날씨는 덥지만 집에만 있기 지루해하는... ",
# "bloggername": "정어리의 알콩달콩 육아일기",
# "bloggerlink": "https://blog.naver.com/lopil22",
# "postdate": "20190804"
#
# },
# {
# "title": "동탄2 레이크빌아파트 <b>에어컨</b> 설치  복층구조 <b>에어컨</b>",
# "link": "https:\/\/blog.naver.com\/koosave?Redirect=Log&logNo=221601372937",
# "description": "https://myaircon.modoo.at/?link=83dcvhmt 화성시 동탄대로 9길20번지 동탄레이크빌아파트 <b>에어컨</b> 설치 캐리어 18평 <b>에어컨</b> +6평 벽걸이 2IN1 제품 구매후 설치 요청 하셧네요! 이집은 복층구조로 층고가 매우 높고... ",
# "bloggername": "콧털이의 바다향기",
# "bloggerlink": "https://blog.naver.com/koosave",
# "postdate": "20190731"
#
# },
# {
# "title": "군산<b>에어컨</b>청소 손쉽게 진행",
# "link": "https:\/\/blog.naver.com\/pjy812?Redirect=Log&logNo=221602288758",
# "description": "작년까지는 선풍기로 여름을 났지만 도저히 버티기힘들어서 전기세의 공포를 안도 <b>에어컨</b>을 켜기로 결정했습니다! 음 <b>에어컨</b>을 켜보니 퀘퀘한 냄새가 스멀스멀 올라오드라구요. 1년넘게 신경을 안써서 그런가... ",
# "bloggername": "미소짓는 고양이",
# "bloggerlink": "https://blog.naver.com/pjy812",
# "postdate": "20190801"
#
# },
# {
# "title": "폭염대비, 보네이도 에어서큘레이터 추천 <b>에어컨</b>과 함께 사용",
# "link": "https:\/\/blog.naver.com\/im_lime?Redirect=Log&logNo=221603719127",
# "description": "여름에 <b>에어컨</b>만 주구장창 작동시킬 수도 없어서 더 폭염대비를 하게 된 것 같다 작지만 성능은 결코... 해도 <b>에어컨</b> 사용을 하지 않아도 될 날씨였는데 벌써 8월에 접어들었다 본격적인 폭염, 무더위 시작이라는... ",
# "bloggername": "달달한 꿀로그♡",
# "bloggerlink": "https://blog.naver.com/im_lime",
# "postdate": "20190802"
#
# },
# {
# "title": "<b>에어컨</b>이 고장나자 더위에 녹아버린 고양이",
# "link": "https:\/\/blog.naver.com\/inbnet?Redirect=Log&logNo=221603003869",
# "description": "다양한 방법들이 있지만 역시나 시원한 <b>에어컨</b> 아래에서 가만히 있는 게 최고인데. 여기 <b>에어컨</b>에 고장나는 바람에 녹아버린 고양이가 있다. 최근 한 온라인 커뮤니티에는 &quot;더위를 견디는 방법에 특이점이 온... ",
# "bloggername": "반려동물뉴스 노트펫",
# "bloggerlink": "https://blog.naver.com/inbnet",
# "postdate": "20190802"
#
# },
# {
# "title": "창문형<b>에어컨</b> 파세코 실사용후기",
# "link": "https:\/\/blog.naver.com\/kinka_s_1029?Redirect=Log&logNo=221602695169",
# "description": "요즘 핫한 창문형 <b>에어컨</b>! 파세코!! #창문형<b>에어컨</b> #파세코 #파세코<b>에어컨</b> #실외기없는<b>에어컨</b> #창문형<b>에어컨</b>파세코 #<b>에어컨</b> #창문형<b>에어컨</b>후기 #솔직한후기 #파세코사용후기 #여름필수템 #파세코설치 저희집은... ",
# "bloggername": "KinKa's",
# "bloggerlink": "https://blog.naver.com/kinka_s_1029",
# "postdate": "20190801"
#
# },
# {
# "title": "<b>에어컨</b> 등급 점검(무조건 1등급 사세요)",
# "link": "https:\/\/blog.naver.com\/soojini65?Redirect=Log&logNo=221605561009",
# "description": "<b>에어컨</b>을 구매하는게 구매시 부담은 있지만 장기적으로 이익입니다. 날씨가 정말 덥네요.오늘 낮에는 주차장이 찜통 같고 34도가 넘는것 같더라고요.거의 후라이팬에 올라가 있는 느낌 이더라고요. <b>에어컨</b>... ",
# "bloggername": "Hurricane 준선아빠의 물생활&맛집&음악etc",
# "bloggerlink": "https://blog.naver.com/soojini65",
# "postdate": "20190804"
#
# },
# {
# "title": "일산 <b>에어컨</b>가스충전, <b>에어컨</b>이전설치 저렴하고 빠른곳~!!!",
# "link": "https:\/\/blog.naver.com\/rlawls307?Redirect=Log&logNo=221590982867",
# "description": "작년 여름 너무나 더워 <b>에어컨</b>이 없는 곳을 갈때면 지치고 힘들었던 기억이 다시금 새록새록 나네요~~ 비도 오고 아직까지는 여름다움을 느끼지 못하는터라 <b>에어컨</b>가동을 하지 않았어요. 올해는 더욱 특별하게... ",
# "bloggername": "일상을 여행처럼. 여행을 일상처럼~",
# "bloggerlink": "https://blog.naver.com/rlawls307",
# "postdate": "20190720"
#
# },
# {
# "title": "수원벽걸이<b>에어컨</b>청소~ 주니아빠만 기억하세요",
# "link": "https:\/\/blog.naver.com\/rhksdn7489?Redirect=Log&logNo=221587951390",
# "description": "수원벽걸이<b>에어컨</b>청소~ 주니아빠만 기억하세요 여름이 왔잖아요. 제가 제일 싫어하는 계절. 저는 진짜... 정말 제정신으로 그나마 있을 수 있는 이유가 <b>에어컨</b>이에요. 저는 진짜 <b>에어컨</b> 여름 내내 끼고 살아요.... ",
# "bloggername": "주니아빠 공식블로그",
# "bloggerlink": "https://blog.naver.com/rhksdn7489",
# "postdate": "20190729"
#
# },
# {
# "title": "울산 남구 <b>에어컨</b>가스충전 신속하고 정확하게",
# "link": "https:\/\/blog.naver.com\/cleanhomekr?Redirect=Log&logNo=221605671334",
# "description": "<b>에어컨</b>이 있어서 그나마 다행이긴 한데 찬바람이 안나온다면.그야말로 큰일이지요. 울산 <b>에어컨</b>가스충전은 ...사실 미리 미리 점검하고 대비해야하는데.... 그러시는분들이 많지 않은것 같습니다. 2주전만해도... ",
# "bloggername": "사랑은마법",
# "bloggerlink": "https://blog.naver.com/cleanhomekr",
# "postdate": "20190805"
#
# },
# {
# "title": "충주 <b>에어컨</b> 청소 처음으로 전문가에게 맡겼어요",
# "link": "https:\/\/blog.naver.com\/loveveggie?Redirect=Log&logNo=221605775509",
# "description": "충주 <b>에어컨</b> 청소 처음으로 전문가에게 맡겼어요~ 한동안 미세먼지없이 깨끗한 날씨가 계속 되고 있어 더워도 깨끗한 하늘에 감사하고 있어요. 하지만... 집에서 공기 청정기를 계속 돌리는 이유.... <b>에어컨</b>을... ",
# "bloggername": "무지무지 좋아해 사랑해",
# "bloggerlink": "https://blog.naver.com/loveveggie",
# "postdate": "20190805"
#
# },
# {
# "title": "대우 커민스415ps 트레일러 가정용벽걸이6평무시동<b>에어컨</b>... ",
# "link": "https:\/\/blog.naver.com\/gima33?Redirect=Log&logNo=221604143372",
# "description": "장비에 무시동 <b>에어콘</b>을 장착해 드립니다. ~~~~~~~~취급제품~~~~~~~~ 화성써모 DC24V 차량.장비용 분리형 무시동<b>에어컨</b>--국산제품 입니다. 실내기.실외기가 분리되어 있습니다. DC24V직접구동으로 전력손실을 줄였고... ",
# "bloggername": "☆JM공조☆화성써모무시동에어콘,에버스 무시동히터",
# "bloggerlink": "https://blog.naver.com/gima33",
# "postdate": "20190803"
#
# },
# {
# "title": "아, 속시원해...(시스템<b>에어컨</b> 청소)",
# "link": "https:\/\/blog.naver.com\/tjswjd1981?Redirect=Log&logNo=221583098424",
# "description": "드디어 <b>에어컨</b> 청소를 끝냈다. <b>에어컨</b> 청소 해야지..해야지 마음은 벌써 먹고 있었는데 마음에 드는 업체를 고르는게 쉽지 않았다. 네이버에 <b>에어컨</b> 청소 시스템<b>에어컨</b> 청소 부산 <b>에어컨</b> 청소로 다 검색을... ",
# "bloggername": "곰이언니 일상기록",
# "bloggerlink": "https://blog.naver.com/tjswjd1981",
# "postdate": "20190711"
#
# },
# {
# "title": "삼성 스탠드 <b>에어컨</b> 셀프청소!",
# "link": "https:\/\/blog.naver.com\/selfbum?Redirect=Log&logNo=221605549058",
# "description": "얼마전 안방에 있는 벽걸이 <b>에어컨</b>을 남편이 셀프청소를 했었는데, 이번에는 거실에 있는 스탠드 <b>에어컨</b>에 도전! https://m.blog.naver.com/selfbum/221596238137 벽걸이<b>에어컨</b> 셀프청소 <b>에어컨</b>청소를 한 번 하고... ",
# "bloggername": "달콤쌉쌉한 놀이터 _by hand it",
# "bloggerlink": "https://blog.naver.com/selfbum",
# "postdate": "20190804"
#
# },
# {
# "title": "평택 센트럴자이 캐리어<b>에어컨</b> 2in1 설치! 평택이전설치",
# "link": "https:\/\/blog.naver.com\/koosave?Redirect=Log&logNo=221604499335",
# "description": "https://myaircon.modoo.at/ 안녕하세요 명인<b>에어컨</b>입니다 오늘은 캐리어<b>에어컨</b> 2in1 매립형 시공 다녀왔어요! 빈집이라 시공이 참 편했는데요 저희 명인은 사람이 없다고 절대 막 하지않습니다. 오늘 고객님이... ",
# "bloggername": "콧털이의 바다향기",
# "bloggerlink": "https://blog.naver.com/koosave",
# "postdate": "20190803"
#
# },
# {
# "title": "서창동 인천<b>에어컨</b>설치 점검 으뜸<b>에어컨</b> 후기",
# "link": "https:\/\/blog.naver.com\/in1055?Redirect=Log&logNo=221603115430",
# "description": "서창동 인천<b>에어컨</b>설치 점검 으뜸<b>에어컨</b> 후기 지난 여름 벽걸이<b>에어컨</b>을 설치하고 우리집 전기세가 너무 많이 나와서 <b>에어컨</b> 설치가 잘못된게 아닌가 하는 의심을 계속 했었다. 우리집이 동네에서 전기세 사용... ",
# "bloggername": "잘 먹고 잘 사는 끼링",
# "bloggerlink": "https://blog.naver.com/in1055",
# "postdate": "20190802"
#
# },
# {
# "title": "셔츠 주머니에 넣는 <b>에어컨</b> 나온다",
# "link": "https:\/\/blog.naver.com\/tech-plus?Redirect=Log&logNo=221599955741",
# "description": "일본 소니가 몸에 착용하는 <b>에어컨</b>을 제작한다. 크라우드 펀딩 방식을 도입해 투자를 받아 진행한다. 착용하는 <b>에어컨</b>은 한여름 옷이 땀으로 흥건하게 젖는 것을 방지하고 체온을 내려주는... ",
# "bloggername": "테크플러스",
# "bloggerlink": "https://blog.naver.com/tech-plus",
# "postdate": "20190730"
#
# },
# {
# "title": "요 며칠 먹는 일상 &amp; <b>에어컨</b> 사서 행복합니다 ㅜ.ㅜ",
# "link": "https:\/\/blog.naver.com\/mitsru79?Redirect=Log&logNo=221605705214",
# "description": "호갱슈 오른발 얼결에 찬조출연 ㅋㅋㅋ 저희요~~ 결혼 14년 만에 <b>에어컨</b> 바꿨어요 도대체가 1시간을 넘게 틀어도 26도에서 절대 안 내려 가던 <b>에어컨</b>... 고물상에 3만원에 팔아 버리고 올 여름 들인 새 <b>에어컨</b>... ",
# "bloggername": "미쯔루의 맛있는 이야기",
# "bloggerlink": "https://blog.naver.com/mitsru79",
# "postdate": "20190805"
#
# },
# {
# "title": "대구원룸<b>에어컨</b>청소, 대현동현장리뷰",
# "link": "https:\/\/blog.naver.com\/myapangt?Redirect=Log&logNo=221603159405",
# "description": "먼지가 유독 많았던 <b>에어컨</b> 안녕하세요? 주말 잘보내시고 계시죠? 이번에도 시원후기를 보여드릴려고 해요. 대구원룸<b>에어컨</b>청소 현장이랍니다. ▲ 원룸<b>에어컨</b> 청소 전 <b>에어컨</b>청소를 꼭 여름에만 받으셔야 하는... ",
# "bloggername": "삐까뻔쩍☆",
# "bloggerlink": "https://blog.naver.com/myapangt",
# "postdate": "20190803"
#
# },
# {
# "title": "딸래미방 <b>에어컨</b>외기 거치용 앵글설치기 더운날씨 땀이 줄줄",
# "link": "https:\/\/blog.naver.com\/mono740128?Redirect=Log&logNo=221603683254",
# "description": "#<b>에어컨</b>앵글 #<b>에어컨</b>외기앵글 #<b>에어컨</b>외기거치대 날씨가 갑짜기 너무덥네요. ^^;;; 7월말까지는 살만한 여름이더만.... 딸래미 공부방에 <b>에어컨</b>설치를 결정하고 삼성 엘지 두곳을 알아보았습니다. 80만원 헉!!... ",
# "bloggername": "[노력]never don't stop",
# "bloggerlink": "https://blog.naver.com/mono740128",
# "postdate": "20190802"
#
# },
# {
# "title": "자동차<b>에어컨</b>청소 : 했는데도 자꾸 냄새난다면 이렇게 해보세요!",
# "link": "https:\/\/blog.naver.com\/wnsqja1161?Redirect=Log&logNo=221603180878",
# "description": "덥다고 귀찮다고 바쁘다고 미뤄왔던 자동차 <b>에어컨</b> 청소.... 더 이상 미룰 수 없다! 자동차 <b>에어컨</b> 청소는 운전자는 물론 가족들의 호흡기 건강을 위해서라도 주기적으로 <b>에어컨</b> 상태를 체크하며 관리해주시는... ",
# "bloggername": "JB모터스_블랙박스,유리막코팅,프리미엄세차",
# "bloggerlink": "https://blog.naver.com/wnsqja1161",
# "postdate": "20190802"
#
# },
# {
# "title": "폭염보다 무서운 <b>에어컨</b> 전기료 절약법 5가지!",
# "link": "https:\/\/blog.naver.com\/slcdream?Redirect=Log&logNo=221601905231",
# "description": "<b>에어컨</b> 전기료 절약법 대 방출! 참을 수 없는 무더위에 가정마다 <b>에어컨</b> 사용이 늘어나고 있습니다. <b>에어컨</b>으로 인한 전기료 폭탄이 무서운 분들을 위하여 <b>에어컨</b> 전기료 절약하는 방법 알려드릴게요~ 1. 적정... ",
# "bloggername": "수도권매립지관리공사",
# "bloggerlink": "https://blog.naver.com/slcdream",
# "postdate": "20190801"
#
# },
# {
# "title": "찬 바람이 안나와요 &lt;부산 남구 대연동 고깃집<b>에어컨</b>청소&gt;",
# "link": "https:\/\/blog.naver.com\/cleanhomekr?Redirect=Log&logNo=221603755074",
# "description": "위풍당당....사이즈가 사람을 압도하는 대형<b>에어컨</b> 입니다. 58평 입니다...보통 이런사이즈의 <b>에어컨</b>들은 기기값도 상당하지만...설치비도 상당 합니다. 이제 딱 3년차인 이 <b>에어컨</b>에 무슨일이 있었던걸까요... ",
# "bloggername": "사랑은마법",
# "bloggerlink": "https://blog.naver.com/cleanhomekr",
# "postdate": "20190802"
#
# },
# {
# "title": "부산 금정구 <b>에어컨</b>냉매가스충전",
# "link": "https:\/\/blog.naver.com\/cleanhomekr?Redirect=Log&logNo=221599332377",
# "description": "연일 찌는듯한 폭염으로 ....부랴 부랴 <b>에어컨</b>을 틀었는데... 찬바람이 안나온다고요 ? 아니면... 뭔가 좀... <b>에어컨</b>을 틀어놨지만...실내온도 30도에서 내려가질 않습니다. 토출온도를 측정해보았습니다.어라~ 엄청... ",
# "bloggername": "사랑은마법",
# "bloggerlink": "https://blog.naver.com/cleanhomekr",
# "postdate": "20190729"
#
# },
# {
# "title": "동탄2신도시 21단지 베라체 매립 <b>에어컨</b> 이전설치 다녀 왔어유... ",
# "link": "https:\/\/blog.naver.com\/koosave?Redirect=Log&logNo=221604484858",
# "description": "https://myaircon.modoo.at/ 안녕하세요 명인<b>에어컨</b>입니다 위니아 벽걸이<b>에어컨</b> 이전설치 문의가 왔네요 22 모델이에요 장비를 바리바리 싸들고 이전설치하러 올라갑니다 우선 실외기 상태부터 봅니다 동관 자른... ",
# "bloggername": "콧털이의 바다향기",
# "bloggerlink": "https://blog.naver.com/koosave",
# "postdate": "20190803"
#
# },
# {
# "title": "벽걸이<b>에어컨</b> 셀프청소",
# "link": "https:\/\/blog.naver.com\/selfbum?Redirect=Log&logNo=221596238137",
# "description": "<b>에어컨</b>청소를 한 번 하고 쓰려고 계속 <b>에어컨</b>가동을 하지 않았었는데.. 계속 밤에는 시원하다못해 서늘하기도했고~ 비가 며칠째 오면서 습기최강이 되버리니, 집에 제습기는 한 대고.. 급한대로 안방... ",
# "bloggername": "달콤쌉쌉한 놀이터 _by hand it",
# "bloggerlink": "https://blog.naver.com/selfbum",
# "postdate": "20190726"
#
# },
# {
# "title": "세류동 <b>에어컨</b> 이전설치 깔끔하게 띠다 붙혔습니다!",
# "link": "https:\/\/blog.naver.com\/koosave?Redirect=Log&logNo=221605464049",
# "description": "https://myaircon.modoo.at/ 안녕하세요 명인입니다 <b>에어컨</b> 이전설치 전문 업체에요! 오늘은 세류동에 사용중인 <b>에어컨</b>을 다른집으로 옮겨 달라는 요청입니다 철거비+ 이동비+ 설치비 사실 철거는 해도 이동은... ",
# "bloggername": "콧털이의 바다향기",
# "bloggerlink": "https://blog.naver.com/koosave",
# "postdate": "20190804"
#
# },
# {
# "title": "<b>에어컨</b>커버 리빈 플랜테리어 인테리어효과",
# "link": "https:\/\/blog.naver.com\/hayul0219?Redirect=Log&logNo=221602982153",
# "description": "요즘 열일하고 있는 우리집 <b>에어컨</b> 습한 날씨에 계속 풀가동 하고 있으니 쉴틈이 없지요 ㅎㅎ 작년에 이사오면서 삼성 무풍<b>에어컨</b> Q9500 2in1 으로 샀는데요. 스탠드형은 제가 <b>에어컨</b>커버 사서 사용 안하는 동안은... ",
# "bloggername": "윤율부부 이야기♥",
# "bloggerlink": "https://blog.naver.com/hayul0219",
# "postdate": "20190802"
#
# },
# {
# "title": "고양이 더운여름나기 <b>에어컨</b> 위에 올라간 까미",
# "link": "https:\/\/blog.naver.com\/gkack1?Redirect=Log&logNo=221605238288",
# "description": "어김없이 찾아온 무더운 여름~ <b>에어컨</b> 없이는 정말 잠시도 견뎌내기가 힘드네요~ 울집 고양이... blog.naver.com 요즘 들어~ <b>에어컨</b> 위에 자주 올라가는 까미 모습을 볼 수 있어요 ㅠㅠ 까미야~ 네... ",
# "bloggername": "함께해요~ 함차가족 일상속으로",
# "bloggerlink": "https://blog.naver.com/gkack1",
# "postdate": "20190804"
#
# },
# {
# "title": "자동차<b>에어컨</b>식초냄새 관리해도 자꾸 난다면???",
# "link": "https:\/\/blog.naver.com\/wnsqja1161?Redirect=Log&logNo=221603149421",
# "description": "타들어가는 듯 뜨거운 날씨를 피해 차에 올라타 <b>에어컨</b>을 트는 그 순간 묘하게 올라오는 자동차 <b>에어컨</b> 식초냄새 심하지는 않아도 거슬릴 정도로 시큼~한 식초 냄새가 <b>에어컨</b>을 켤 때마다 반복적으로... ",
# "bloggername": "JB모터스_블랙박스,유리막코팅,프리미엄세차",
# "bloggerlink": "https://blog.naver.com/wnsqja1161",
# "postdate": "20190802"
#
# },
# {
# "title": "<b>에어컨</b> 관리 회원가입 안내",
# "link": "https:\/\/blog.naver.com\/loowi?Redirect=Log&logNo=221605238431",
# "description": "여름 한철동안 <b>에어컨</b>이 말썽을 부리면 정말 힘이 듭니다. <b>에어컨</b>이 정상인지 비정상인지를 고객분들이 확인하시기는 쉽지 않습니다. 만약 수리를 할 경우에도 바가지를 쓰지 않았나 의구심이 들기도... ",
# "bloggername": "실사구시(實事求是)",
# "bloggerlink": "https://blog.naver.com/loowi",
# "postdate": "20190804"
#
# },
# {
# "title": "시스템<b>에어컨</b>교체, 리뉴얼 현장, 영문설명서",
# "link": "https:\/\/blog.naver.com\/sacare?Redirect=Log&logNo=221603164547",
# "description": "10여년전의 시스템<b>에어컨</b> 설치현장 배관공사는 이미 되어 있으므로, 실외기/실내기 만 신제품으로 교체 (#시스템<b>에어컨</b>교체) 하여 사용할 수 있습니다. 배관공사를 하지 않으므로 천정인테리어 공사 불필요.... ",
# "bloggername": "(주)에이케어 - 크린룸, 냉/난방.환기, 공조제어",
# "bloggerlink": "https://blog.naver.com/sacare",
# "postdate": "20190802"
#
# },
# {
# "title": "엘지 <b>에어컨</b> 휘센 투인원 설치했어요",
# "link": "https:\/\/blog.naver.com\/mirikhan?Redirect=Log&logNo=221606205733",
# "description": "그래서 올해는 <b>에어컨</b>을 설치하기로 했습니다 저기 저 공간이 <b>에어컨</b> 자리! 거실 구석인데 원래는 티비 선반장이 길게 있던 자리에요 여기가 <b>에어컨</b> 놓을 곳! 하얀 박스를 열면 콘센트와 <b>에어컨</b> 호스를 연결할 수... ",
# "bloggername": "핑크캣츠, 데일리 라이프",
# "bloggerlink": "https://blog.naver.com/mirikhan",
# "postdate": "20190805"
#
# },
# {
# "title": "k5<b>에어컨</b>컴프레서교환",
# "link": "https:\/\/blog.naver.com\/you589?Redirect=Log&logNo=221600069346",
# "description": "k5 <b>에어컨</b>컴프레셔 교환 작업 합니다 1달전에 컴프레셔콘트롤 밸브 교체하고 플러싱작업과 <b>에어컨</b>가스 완충하고 출고 그때 증상과 같다고 1달만에 다시 입고 하셨습니다 점검 저번 과 같음 부품점에 사정 예기... ",
# "bloggername": "하남대신카 010-6336-3711",
# "bloggerlink": "https://blog.naver.com/you589",
# "postdate": "20190730"
#
# },
# {
# "title": "신정이펜하우스 캐리어이동식<b>에어컨</b> 보조샤시 설치후기",
# "link": "https:\/\/blog.naver.com\/sunsky64?Redirect=Log&logNo=221604187302",
# "description": "오늘은 양천구 신정동에 있는 신정 이펜하우스 아파트에서 캐리어이동식 <b>에어컨</b> 설치작업을 진행하였습니다. 캐리어 이동식 <b>에어컨</b> 모델명 CPA-A072PDA 입니다. 냉방성능도 좋고 소음도 적은... ",
# "bloggername": "린나이 양천구 공식 대리점(시티에너지) 블로그",
# "bloggerlink": "https://blog.naver.com/sunsky64",
# "postdate": "20190803"
#
# },
# {
# "title": "신일 프리미엄 냉/온 이동식 <b>에어컨</b>(SMA-P12000AU) 체험단 모집",
# "link": "https:\/\/blog.naver.com\/shinil1959?Redirect=Log&logNo=221578255240",
# "description": "신일이 지금부터 무더운 여름을 슬기롭게 대처하게 해 줄 신일 프리미엄 냉/온 이동식 <b>에어컨</b>(SMA-P12000AU) 체험단을 모집합니다! 여름에는 <b>에어컨</b>으로 시원하게, 겨울에는 난방기로 따뜻하게 이중으로... ",
# "bloggername": "신일 공식 블로그",
# "bloggerlink": "https://blog.naver.com/shinil1959",
# "postdate": "20190705"
#
# },
# {
# "title": "여름철 에너지를 절약하는 <b>에어컨</b> 사용방법!",
# "link": "https:\/\/blog.naver.com\/damyanggun?Redirect=Log&logNo=221602136143",
# "description": "[여름철 에너지를 절약하는 <b>에어컨</b> 사용방법] 맑은 하늘에 구름이 너무 예쁜 8월의 첫날입니다 :-) 하지만 후끈한 더위와 함께 폭염이 계속되고 있는데요~ <b>에어컨</b> 없이는 생활하기 불편한 요즘, 여름철 에너지... ",
# "bloggername": "대숲맑은담양",
# "bloggerlink": "https://blog.naver.com/damyanggun",
# "postdate": "20190801"
#
# },
# {
# "title": "엘지 휘센 <b>에어컨</b> (FQ17 모델), 전주 전자랜드 인후점에서",
# "link": "https:\/\/blog.naver.com\/yogiwalker?Redirect=Log&logNo=221601501551",
# "description": "우리 집에는 현재 <b>에어컨</b>이 벽걸이형 캐리어 하나 안방에 있다. 안방에서만 생활하는 게 아니고 날은 더워지고 습해지고.. 거실에 <b>에어컨</b>이 필요하다고 간절히 느꼈다. 선풍기 4대, <b>에어컨</b> 1개 풀가동해도... ",
# "bloggername": "강희수가 쏘아올린 작은 공",
# "bloggerlink": "https://blog.naver.com/yogiwalker",
# "postdate": "20190731"
#
# },
# {
# "title": "서재 에코폴리스동화아이위시2차 2in1 <b>에어컨</b>청소",
# "link": "https:\/\/blog.naver.com\/myapangt?Redirect=Log&logNo=221603095022",
# "description": "이렇게 더운 날은 <b>에어컨</b>없이 지내긴 힘든 것 같아요. 남은 여름동안 열일할 <b>에어컨</b>의 청결상태는 점검해보셨어요?? 에코폴리스동화아이위시2차의 현장 <b>에어컨</b>은 곰팡이가 있었어요. 여러분의 <b>에어컨</b>은... ",
# "bloggername": "삐까뻔쩍☆",
# "bloggerlink": "https://blog.naver.com/myapangt",
# "postdate": "20190802"
#
# },
# {
# "title": "우리 집 <b>에어컨</b>이 정상인지 확인하는 방법",
# "link": "https:\/\/blog.naver.com\/loowi?Redirect=Log&logNo=221596460772",
# "description": "<b>에어컨</b>을 사용하시다 보면 좀처럼 시원하지 않다고 느끼실 때가 있다면 다음과 같은 간단한 방법으로 <b>에어컨</b>의 상태를 검사하실 수 있습니다. 먼저 <b>에어컨</b>은 실외 온도 35도, 실내 온도 27도일 때를 기준으로... ",
# "bloggername": "실사구시(實事求是)",
# "bloggerlink": "https://blog.naver.com/loowi",
# "postdate": "20190726"
#
# },
# {
# "title": "찜질방<b>에어컨</b> 청소",
# "link": "https:\/\/blog.naver.com\/gksdmsqlfkd?Redirect=Log&logNo=221603742340",
# "description": "찜질방<b>에어컨</b>청소 왔어요 찜질방은 많은사람이 이용하는곳이라 오염이 심합니다 드레인안에 오염이 심하죠?? 프론트판넬도 시커먼스입니다 이곳<b>에어컨</b>은 실내기가 전상봉에서 떨어져있어서 놀랬어요... ",
# "bloggername": "곰팡이제거 책임시공 01037500111",
# "bloggerlink": "https://blog.naver.com/gksdmsqlfkd",
# "postdate": "20190802"
#
# },
# {
# "title": "언더베드 DOMETIC <b>에어컨</b> 설치2",
# "link": "https:\/\/blog.naver.com\/jamting7?Redirect=Log&logNo=221603682071",
# "description": "다음에 양 사이드에도 고정끈을 달아줘서 걸수있도록 해야겠다 우리 가족을 시원함으로 이끌어줄 도메틱<b>에어컨</b>장착은 이렇게 끝냈다 상부토출구는 뽑아서 <b>에어컨</b>쪽에 정리를 해놓고 짐정리 완료ㅎㅎ 짐이 너무... ",
# "bloggername": "공산당의 이야기...",
# "bloggerlink": "https://blog.naver.com/jamting7",
# "postdate": "20190802"
#
# },
# {
# "title": "리빈 <b>에어컨</b>커버 LG 벽걸이 <b>에어컨</b>커버 잘고르는 방법",
# "link": "https:\/\/blog.naver.com\/iameunu?Redirect=Log&logNo=221604609618",
# "description": "2019년형 세상예쁜 삼성 엘지 휘센 벽걸이 스탠드 <b>에어컨</b>커버 : Glober 2019년형 세상예쁜 삼성 엘지 휘센 벽걸이 스탠드 <b>에어컨</b>커버 smartstore.naver.com 올해 5월에 안방에도 <b>에어컨</b>을 설치했습니다. 아기랑 안방에서... ",
# "bloggername": "즐거운 은유♪",
# "bloggerlink": "https://blog.naver.com/iameunu",
# "postdate": "20190803"
#
# },
# {
# "title": "대곡역동화타운의 스탠드&amp;벽걸이 <b>에어컨</b>청소",
# "link": "https:\/\/blog.naver.com\/myapangt?Redirect=Log&logNo=221600974266",
# "description": "<b>에어컨</b>틀고~ 시원하게 집에서 좋아하는 영화보며 보내는 것도 정말 좋은 것 같아요! 그치만, 휴가내내 함께 보낼 <b>에어컨</b>은 점검해보셨나요? 그래서 오늘은 대곡역동화타운에 <b>에어컨</b>청소를 다녀온 후기를... ",
# "bloggername": "삐까뻔쩍☆",
# "bloggerlink": "https://blog.naver.com/myapangt",
# "postdate": "20190801"
#
# },
# {
# "title": "대전<b>에어컨</b>설치 잘하는 집",
# "link": "https:\/\/blog.naver.com\/you173?Redirect=Log&logNo=221579232330",
# "description": "예전 같았으면 <b>에어컨</b> 없이 선풍기하나만으로도 살았을 텐 데 더위가 벌써부터 기승을 부려 대전에서도 35도를 넘어서고 있습니다. 무척이나 더워진 만큼 필수 아이템이 되어버린 대전에<b>에어컨</b> <b>에어컨</b>이라는... ",
# "bloggername": "올갱이 나만의 인테리어디자인",
# "bloggerlink": "https://blog.naver.com/you173",
# "postdate": "20190706"
#
# },
# {
# "title": "2019. 7. 27 토스카 <b>에어컨</b> 컴프레셔 교환",
# "link": "https:\/\/blog.naver.com\/jisu1405?Redirect=Log&logNo=221598151279",
# "description": "한창 무더위가 시작될 무렵에 <b>에어컨</b>에서 찬바람이 나오지 증상이 발생했다. 지난번 회사 직원... <b>에어컨</b>가스 충전기를 통해서 저압팽창밸브 압력이 30~40psi 사이에 있어야 정상인데 50psi이상을 가리켰다...... ",
# "bloggername": "나의이야기",
# "bloggerlink": "https://blog.naver.com/jisu1405",
# "postdate": "20190728"
#
# },
# {
# "title": "바람지움 스탠드<b>에어컨</b> 바람막이 직바람 추위 막아줘요",
# "link": "https:\/\/blog.naver.com\/ckypyj?Redirect=Log&logNo=221605408420",
# "description": "쇼파옆에 자리하고 있는 엘지휘센<b>에어컨</b> 기본기능만 있는 <b>에어컨</b>을 구입했더니 바람방향을 바꾸는 기능이 없어요. <b>에어컨</b>을 틀면 쇼파쪽으로 직바람이 불어 쇼파에 앉아있으면 너~무 춥답니다. 그래서 긴... ",
# "bloggername": "♥요술핑거 꽃이 핀다♥",
# "bloggerlink": "https://blog.naver.com/ckypyj",
# "postdate": "20190804"
#
# },
# {
# "title": "20년된 LG <b>에어컨</b> 전기료는?",
# "link": "https:\/\/blog.naver.com\/sep25341?Redirect=Log&logNo=221597913785",
# "description": "우리집 <b>에어컨</b>은 20년이 지난 LG <b>에어컨</b> 입니다. 이전에 테스트한 전기 사용량입니다. 우리집 <b>에어컨</b> 전기료 얼마? 실사용하며계산해보기 [1906] 전기료는 왜 전기세라고 할까요?해마다 반복되는... ",
# "bloggername": "◀MOMO777.US.MS▶",
# "bloggerlink": "https://blog.naver.com/sep25341",
# "postdate": "20190728"
#
# },
# {
# "title": "안양 용인 수원<b>에어컨</b>가스충전은 <b>에어컨</b>나라에서!",
# "link": "https:\/\/blog.naver.com\/auswjd86?Redirect=Log&logNo=221604854876",
# "description": "작년보다 덜 덥다는 말은 사실이 아닌 건지 더워서 녹아버릴 것 같은 날들이 계속되고 있어서 하루 종일 <b>에어컨</b>을 틀고 있는데요 설정 온도에 비해 바람이 시원하지 않은 것 같으시다면 <b>에어컨</b>의 냉매가... ",
# "bloggername": "Emjay's Studio",
# "bloggerlink": "https://blog.naver.com/auswjd86",
# "postdate": "20190804"
#
# },
# {
# "title": "화성 <b>에어컨</b> 이전설치.. 멀다 멀어 한적한 한 시골에서 <b>에어컨</b>... ",
# "link": "https:\/\/blog.naver.com\/koosave?Redirect=Log&logNo=221604534238",
# "description": "https://myaircon.modoo.at/ 안녕하세요 명인입니다 오늘은 화성 남양에 한 시골마을 주택에 <b>에어컨</b> 설치 다녀왔습니다. 주택 입니다 저도 나중에 이런집 하나 지어서 살고 싶어요.. 부럽부럽.. 오늘 설치할 <b>에어컨</b>은... ",
# "bloggername": "콧털이의 바다향기",
# "bloggerlink": "https://blog.naver.com/koosave",
# "postdate": "20190803"
#
# },
# {
# "title": "눈  내리는 <b>에어컨</b>청소",
# "link": "https:\/\/blog.naver.com\/gksdmsqlfkd?Redirect=Log&logNo=221596937881",
# "description": "휘센인버터<b>에어컨</b> 입니다 <b>에어컨</b>에 눈 내린거같죠?? 오우~~~~ 온통 먼지예요 밑빤이 까맣죠?? 물 넘친거더라구요 ㅠ ㅠ 눈 내리듯 먼지가 그득 내려앉아 있습니다 밑판은 검은색이길래 보니 오염된물이 가득해... ",
# "bloggername": "곰팡이제거 책임시공 01037500111",
# "bloggerlink": "https://blog.naver.com/gksdmsqlfkd",
# "postdate": "20190727"
#
# },
# {
# "title": "폭염속의 <b>에어컨</b> 전기료 측정",
# "link": "https:\/\/blog.naver.com\/sugo100?Redirect=Log&logNo=221604292787",
# "description": "작년에는 2시에 <b>에어컨</b>을 가동으로 다음날 9시쯤에 껐는데 올해는 너무 더워서 스탠드 <b>에어컨</b>은 저녁 8~9시 사이에 켜서 새벽 0시~2시 사이까지만 켜고 나머지 시간대는 전부 벽걸이 <b>에어컨</b> 사용중입니다.... ",
# "bloggername": "담쥐의 하루일과",
# "bloggerlink": "https://blog.naver.com/sugo100",
# "postdate": "20190803"
#
# },
# {
# "title": "울산 <b>에어컨</b>냉매가스 충전 잘하는곳",
# "link": "https:\/\/blog.naver.com\/cleanhomekr?Redirect=Log&logNo=221601611430",
# "description": "그나마 벽에 달려있는 <b>에어컨</b>이 제기능을 발휘 못한다면 정말 살맛 안날거 같습니다. 오늘은 북구... 울산 <b>에어컨</b>냉매가스 충전은 저희 울산클린에 맡겨주세요. 고품격 서비스로 보답하겠습니다. 문의전화는 010... ",
# "bloggername": "사랑은마법",
# "bloggerlink": "https://blog.naver.com/cleanhomekr",
# "postdate": "20190801"
#
# },
# {
# "title": "아우디 수원 서비스센터 - <b>에어컨</b> 고장",
# "link": "https:\/\/blog.naver.com\/1004dkny?Redirect=Log&logNo=221603726064",
# "description": "이 날씨에 아우디 <b>에어컨</b> 고장 하지만 다행히 별문제 아니었음 그렇게 #차계부 폭염경보가 내리는 이 날씨에 아까까지 멀쩡하던 제씨가 커피 한잔 마시고 나왔더니 갑자기 <b>에어컨</b>이 먹통이다. 히터도 먹통이다... ",
# "bloggername": "독과 노인",
# "bloggerlink": "https://blog.naver.com/1004dkny",
# "postdate": "20190802"
#
# },
# {
# "title": "<b>에어컨</b> 실외기 자가수리",
# "link": "https:\/\/blog.naver.com\/semo1999?Redirect=Log&logNo=221602720615",
# "description": "<b>에어컨</b>이 고장난다면 난감하다. <b>에어컨</b>수리요청은 2주일이나 지체되고 수리기사가 올때까지 더위에 지쳐가는 가족들을 보게 될 것이다. <b>에어컨</b>을 틀었는데 냉기는 안나오고 뜨뜨미지근한 바람이 불어온다면... ",
# "bloggername": "나마음",
# "bloggerlink": "https://blog.naver.com/semo1999",
# "postdate": "20190802"
#
# },
# {
# "title": "언더베드 DOMETIC <b>에어컨</b> 설치 1",
# "link": "https:\/\/blog.naver.com\/jamting7?Redirect=Log&logNo=221603229579",
# "description": "우리 빨갱이에 <b>에어컨</b>을? 음.., 솔직히 고민 많이했다 금액도 있고 공간도 차지하고...ㅠㅠ 근데... 하면서 항상 가득...ㅠㅠ설치 가다도 만들고원래는 내가 직접해야 하는데 <b>에어컨</b> 설치한다니 르노마스터... ",
# "bloggername": "공산당의 이야기...",
# "bloggerlink": "https://blog.naver.com/jamting7",
# "postdate": "20190802"
#
# },
# {
# "title": "#만트럭무시동<b>에어컨</b>",
# "link": "https:\/\/blog.naver.com\/guard3337?Redirect=Log&logNo=221606387147",
# "description": "#만트럭무시동<b>에어컨</b> #경기도용인무시동<b>에어컨</b> #용인무시동<b>에어컨</b> #이천무시동<b>에어컨</b> 만트럭 무시동 <b>에어컨</b> 입니다 작업 내용을 간단하게 알려드립니다 - 캐리어 6평형 가정용 <b>에어컨</b> - 실내,외기 - 보조 배터리... ",
# "bloggername": "사람과 트럭이야기",
# "bloggerlink": "https://blog.naver.com/guard3337",
# "postdate": "20190805"
#
# },
# {
# "title": "2019 삼성 <b>에어컨</b> 모델명 쉽게 보는 방법 2 (스탠드 편)",
# "link": "https:\/\/blog.naver.com\/onlygod831?Redirect=Log&logNo=221606381207",
# "description": "지난주에는 삼성 무풍 벽걸이 <b>에어컨</b> 모델명 쉽게 보는 법에 대해 포스팅했었는데, 반응이 아주 좋았어요!! 성원에 힘입어 오늘은 &quot;스.탠.드&quot; <b>에어컨</b> 모델명 보는 법에 대해 알려드릴까 합니다.... ",
# "bloggername": "삼성MNS 공식블로그(삼성플립/ 복합기/가전)",
# "bloggerlink": "https://blog.naver.com/onlygod831",
# "postdate": "20190805"
#
# },
# {
# "title": "대체 이게 무슨 냄새야? 자동차 <b>에어컨</b> 냄새 잡는 꿀팁!",
# "link": "https://www.driveind.com/1864?category=498744",
# "description": "여름 무더위가 찾아오면서 자동차를 타면 바로 <b>에어컨</b>부터 켜는 운전자들이 늘고 있는데요. 하지만 시원한 바람을 맞기도 전에 <b>에어컨</b>을 켰을 때 나는 꾸리꾸리하고 퀴퀴한 냄새로 인해 불쾌감을 느끼는 경우가... ",
# "bloggername": "DB손해보험 내차사랑 블로그 In:D",
# "bloggerlink": "https://www.driveind.com/",
# "postdate": "20190717"
#
# },
# {
# "title": "자동차고장 수리경험담-1: <b>에어컨</b> 냉매충전",
# "link": "https:\/\/blog.naver.com\/choi_s_h?Redirect=Log&logNo=221602282279",
# "description": "그러고 보니 제 3년 전에 자동차 <b>에어컨</b>을 고친 경험이 생각나네요. 고쳤다가 보다는 냉매만 충전하였습니다. 그 때 제 애마(SM5)가 이미 10살을 넘겼을 때입니다. 당시 그해 4월부터 자동차 <b>에어컨</b>이 시원찮더니... ",
# "bloggername": "Common Sense, Science & Engineering",
# "bloggerlink": "https://blog.naver.com/choi_s_h",
# "postdate": "20190801"
#
# },
# {
# "title": "시트지달인 의 #벽걸이<b>에어컨</b>물떨어짐 셀프수리       충격적... ",
# "link": "https:\/\/blog.naver.com\/topfilm2271?Redirect=Log&logNo=221604674934",
# "description": "벽걸이 <b>에어컨</b>에서 물이 똑 똑 떨어지나요? 급한 마음에 &quot;검색.... 검색&quot; <b>에어컨</b> 수리업체에 문의하셨는데 돌아오는 대답은... &quot;2주 기다리세요...&quot; &quot;수리비 20만~30원 이상 입니다&quot; &quot;바뻐서 못해드려요..&quot; &quot;배수관... ",
# "bloggername": "달인의 시트지 리폼시공",
# "bloggerlink": "https://blog.naver.com/topfilm2271",
# "postdate": "20190803"
#
# },
# {
# "title": "공주<b>에어컨</b> 설치 뚱이네<b>에어컨</b>에서",
# "link": "https:\/\/blog.naver.com\/you173?Redirect=Log&logNo=221559465091",
# "description": "이제 본격적인 여름이 시작되면서 공주<b>에어컨</b> 성수기가 시작 되었습니다. 이사철에는 같이 <b>에어컨</b>을 주로 설치하시는 경우가 대부분 인 데, <b>에어컨</b>만 여름에 설치하시는 분들은 시간도 오래 걸리고 홈쇼핑으로... ",
# "bloggername": "올갱이 나만의 인테리어디자인",
# "bloggerlink": "https://blog.naver.com/you173",
# "postdate": "20190611"
#
# }
# ]
# }

# %%
import requests
from urllib.parse import urlparse
import json

keyword = "YOLO life"
url = "https://openapi.naver.com/v1/search/blog?query=" + keyword
result = requests.get(urlparse(url).geturl(),
                      headers={"X-Naver-Client-Id":client_id , "X-Naver-Client-Secret":client_secret})
print(result.json())
# Out:
# {'lastBuildDate': 'Mon, 05 Aug 2019 17:56:40 +0900', 'total': 5854, 'start': 1, 'display': 10, 'items': [{'title': '<b>Yolo Life</b>', 'link': 'https://blog.naver.com/w_t1208?Redirect=Log&logNo=221079206143', 'description': "오늘 포스팅의 제목을 '<b>Yolo Life</b>'로 정한건 미래를 위해 아끼고 고민하던 소비생활을 지금 현재의 나에게 좀 더 투자하는 쪽으로 바꿨고 그러고 난 뒤의 나의 정신적으로나 육체적으로 더 자유롭다는 느낌을... ", 'bloggername': 'UnderCore', 'bloggerlink': 'https://blog.naver.com/w_t1208', 'postdate': '20170822'}, {'title': '<b>Yolo LIfe</b> = 돈이 전부가 아닌 삶', 'link': 'https://blog.naver.com/stoneironeng2?Redirect=Log&logNo=221532033623', 'description': '<b>YOLO</b>... 란 ‘You Only Live Once(한 번뿐인 인생)’의 약자라고 합니다. 결국 한 번뿐인 인생에서 기회를... 행복의 순간들을 더 많이 만들어 가기 위한 새로운 <b>Life</b> Style 인 거죠.. Minimal <b>Life</b>.....란 필요한 것 이외에는... ', 'bloggername': '인테리어 전문 블로그 입니다.', 'bloggerlink': 'https://blog.naver.com/stoneironeng2', 'postdate': '20190508'}, {'title': '<b>YOLO LIFE</b> 나를 위한 오사카여행', 'link': 'https://blog.naver.com/hannapride?Redirect=Log&logNo=221080882566', 'description': '<b>YOLO LIFE</b>를 성실히 실행하고 있는 한 사람으로써 준비해 보는 오사카 욜로여행! 간사이 지방이 혼자서도 여행하기 정말 좋은 곳이자~ 그리고 같은 욜로족 친구와 함께 청춘을 불태우기도 정말 좋은 곳이라서... ', 'bloggername': '여행은 인생 필수조건이다', 'bloggerlink': 'https://blog.naver.com/hannapride', 'postdate': '20170824'}, {'title': '[충무로아트센터] 김진향작가님 강연 /  바로, 지금 <b>YOLO LIFE</b> !!', 'link': 'https://blog.naver.com/yungiyun7788?Redirect=Log&logNo=221067377852', 'description': '@ 김진향작가님 강연_욜로 라이프 여러분들도 #욜로라이프 (<b>YOLO LIFE</b>) 들어 보신 적 있으신가요? 요즘 많이 핫 ! 한 단어죠 ^^ You Only Live Once 앞 글자만 따온 약자로 한 번뿐인 인생 이라는 뜻이라고 하네요 !!... ', 'bloggername': '인생은 freedom', 'bloggerlink': 'https://blog.naver.com/yungiyun7788', 'postdate': '20170805'}, {'title': '한번뿐인 인생 오사카에서 <b>YOLO Life</b> 계획', 'link': 'https://blog.naver.com/cbn4140?Redirect=Log&logNo=221086580824', 'description': '한번뿐인 인생, 오사카에서 즐기는 <b>YOLO Life</b> 계획을 짜봤는데요 요즘 주유패스 혜택이 더 커져서 꼭 다시한번 주유패스를 이용해 오사카 여행을 해보고 싶더라구요 정말 이 계획대로 여행갔다 올 수 있었으면... ', 'bloggername': '반짝', 'bloggerlink': 'https://blog.naver.com/cbn4140', 'postdate': '20170831'}, {'title': '필수패스 한큐 투어리스트 패스로 떠나는 <b>YOLO Life</b> 여행', 'link': 'https://blog.naver.com/jamjma98?Redirect=Log&logNo=221067249710', 'description': "여행 컨셉은 요즘 유행한다는 <b>YOLO</b>. 바로 'You Only Live Once'의 약자로 '한 번 뿐인 인생 너를 위해 즐겨라!'라는 의미로 사용되고 있지요. 그런 점에서 간사이, 고베, 교토가 있는 간사이여행은 <b>YOLO</b>를 위해 적합한... ", 'bloggername': '너구리 가족의 땅굴 밖 여행', 'bloggerlink': 'https://blog.naver.com/jamjma98', 'postdate': '20170805'}, {'title': '취준생들의 행복을 지원하는 젊다네 <b>yolo life</b> 프로젝트... ', 'link': 'https://blog.naver.com/nsandyk?Redirect=Log&logNo=221561388390', 'description': '(상시적으로 취준생들의 행복을 지원하는 <b>yolo life</b> 프로젝트를 진행하고 있습니다^^) 안녕하세요! 이번에 정말 운좋게 젊다네 yolo 프로그램에 선정되어 간만의 여유를 즐길 수 있었던 5월이었습니다 J 후기 너무... ', 'bloggername': '젊.다.네 - 인재다락방! 취업 전략과 실무 내공을!', 'bloggerlink': 'https://blog.naver.com/nsandyk', 'postdate': '20190613'}, {'title': '한 번 뿐인 인생, <b>YOLO LIFE</b>!', 'link': 'https://blog.naver.com/fundu2015?Redirect=Log&logNo=221065160637', 'description': "(* 2016년에는 옥스포드 사전에 신조어로 등록되기도 했다고 합니다!) # '<b>YOLO LIFE</b>' 란? '먼 미래를 걱정하기 보다는 지금 현실에서 할 수 있는것을 행하며 경험하자' 즉, 자기 자신의행복을 가장 중요시... ", 'bloggername': '나를 위한 투자, P2P금융 플랫폼 펀듀', 'bloggerlink': 'https://blog.naver.com/fundu2015', 'postdate': '20170802'}, {'title': '[미혼가구]진정한 <b>YOLO Life</b>는 외로움과 경제력으로부터... ', 'link': 'https://blog.naver.com/captain_kang?Redirect=Log&logNo=221517704873', 'description': '미혼 가구 무섭게 늘어난다··· 2043년 65세 이상 미혼 가구주 100만명 미혼가구의 재무관심 분야 상담 주제 [미혼가구] 진정한 <b>YOLO Life</b>는 외로움 극복과 경제력으로부터 나온다! 요즘 미혼이신 분들의 가장 큰... ', 'bloggername': '재무상담, 자산관리, 보험, 펀드, 상조', 'bloggerlink': 'https://blog.naver.com/captain_kang', 'postdate': '20190422'}, {'title': '[루트컨설팅/HRD정보] 한번뿐인 인생(<b>YOLO Life</b>)을 위한... ', 'link': 'https://blog.naver.com/consulting14?Redirect=Log&logNo=221084694823', 'description': '[루트컨설팅/HRD정보] 한번뿐인 인생(<b>YOLO Life</b>)을 위한, 건강한 목표수립! 2017년 주요 소비 트렌드로 떠오른 단어가 있습니다. 바로 욜로(YOLO-Your only live once)인데요. 20-30대 세대에서 주목을 받는 이 키워드는... ', 'bloggername': '세상과 나누고 싶은 진짜 교육, 루트컨설팅', 'blo ...
